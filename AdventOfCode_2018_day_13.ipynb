||    |   |\\+++--+------+-+/ |  |   /-------++--+-+--\\      |    |    ||  || |   ||    |  | |   |  |||   |      ||            |   |||  ||  |          
||    |  /+-+++--+------+-+--+--+---+-------++--+-+--+------+----+----++--++-+---++----+--+-+---+--+++\\  |      ||            |   |||  ||  |          
||    |  || |||  |      | |  |  |   |       ||  | |  |      |    |    ||  || |   ||    |  | |   |  ||\\+--+------++------------/   |||  |^  |          
||    |  || |||  |      | |  \\--+---+-------++--+-+--+------+----/    ||  || |   ||    |  | |   |  || |  |      ||                |||  ||  |          
||    |  || |||  |      | |     |   |       ||  | |  |      |         ||  || |   ||    |  | |   |  || |  |      ||                |||  ||  |          
||    \\--++-+++--+------+-+-----+---+-------++--+-/  |      |         ||  || |   ||    \\--+-+---+--++-+--+------++----------------++/  ||  |          
||       || |||  |      \\-+-----+---+-------++--/    |      |         ||  || |   ||       | |   |  || |  |      |\\----------------++---++->/          
||       || ||\\--+--------+-----+---+-------++-------+------+-<-------/|  || |   ||       | \\---+--++-+--+------+-----------------++---+/             
||       |\\-++---+--------+-----+---+-------++-------+------+----------+--+/ |   ||       |     |  || |  |      |                 ||   |              
\\+-------+--++>--+--------+-----+---+-------++-------+------/          |  |  \\---++-------+-----+--++-+--/      |                 ||   |              
 |       |  ||   \\--------+-----+---+-------++-------+-----------------+--+------++-------+-----/  || |         |                 ||   |              
 |       |  \\+------------+-----+---+-------/|       |                 |  \\------++-------+--------++-+---------+-----------------++---/              
 |       |   \\------------/     \\---+--------/       |                 |         \\+-------+--------++-+---------+-----------------+/                  
 |       |                          |                |                 \\----------+-------+--------/| |         |                 |                   
 \\-------+--------------------------+----------------+----------------------------/       |         \\-+---------+-----------------/                   
         \\--------------------------+----------------+------------------------------------+-----------/         |                                     
                                    \\----------------/                                    \\---------------------/                                     """

# %% [markdown]
# ## Part One

# %%
carts = []
cross = set()
corners = {}
lines = {}

DIR_D = (0,1)
DIR_R = (1,0)
DIR_U = (0, -1)
DIR_L = (-1,0)


class cart:
  def __init__(self, x, y, d):
    self.p = (x,y)
    self.d = d
    self.n = 'l'
    
  def rot_l(self):
    self._rot()
    
  def _rot(self):
    if self.d == DIR_D:
      self.d = DIR_R
      return

    if self.d == DIR_R:
      self.d = DIR_U
      return
    
    if self.d == DIR_U:
      self.d = DIR_L
      return
    
    if self.d == DIR_L:
      self.d = DIR_D
      return
    
    
  def rot_r(self):
    # Hacky McHackFace 
    self._rot()
    self._rot()
    self._rot()
    
  def cross(self):
    if self.n == 'l':
      self.rot_l()
      self.n = 's'
      return
    
    if self.n == 's':
      self.n = 'r'
      return
    
    if self.n == 'r':
      self.rot_r()
      self.n = 'l'
      return
    
  def corner(self):
    c = corners[self.p]
    if c == '/': 
      if self.d == DIR_U or self.d == DIR_D:
        self.rot_r()
      else:
        self.rot_l()
        
      return 
        
    if c == '\\':
      if self.d == DIR_U or self.d == DIR_D:
        self.rot_l()
      else:
        self.rot_r()
      
  def move(self):
    px,py = self.p
    vx,vy = self.d
    
    self.p = (px+vx, py+vy)
    
    if self.p in cross:
      self.cross()
    if self.p in corners:
      self.corner()
      
      
def move_carts():
  pos = set()

  for c in carts:
    c.move()
    if c.p in pos:
      return c.p
    
    pos.add(c.p)
    
  return None


for y, line in enumerate(input_map.splitlines(), 0):
  for x, c in enumerate(list(line), 0):
    if c == '+':
      cross.add((x,y))
    if c == '/' or c == "\\":
      corners[(x,y)] = c
      
    if c == 'v':
      carts.append(cart(x,y, DIR_D))
    if c == '>':
      carts.append(cart(x,y, DIR_R))
    if c == '^':
      carts.append(cart(x,y, DIR_U))
    if c == '<':
      carts.append(cart(x,y, DIR_L))

      
col = None
while col == None:
  col = move_carts()

x,y = col
print("{},{}".format(x, y))
# Out:
# 119,41

# %% [markdown]
# ## Part Two

# %%
carts = []
cross = set()
corners = {}
lines = {}

DIR_D = (0,1)
DIR_R = (1,0)
DIR_U = (0, -1)
DIR_L = (-1,0)


class cart:
  def __init__(self, x, y, d):
    self.p = (x,y)
    self.d = d
    self.n = 'l'
    self.dead = False
    
  def rot_l(self):
    self._rot()
    
  def _rot(self):
    if self.d == DIR_D:
      self.d = DIR_R
      return

    if self.d == DIR_R:
      self.d = DIR_U
      return
    
    if self.d == DIR_U:
      self.d = DIR_L
      return
    
    if self.d == DIR_L:
      self.d = DIR_D
      return
    
    
  def rot_r(self):
    # Hacky McHackFace 
    self._rot()
    self._rot()
    self._rot()
    
  def cross(self):
    if self.n == 'l':
      self.rot_l()
      self.n = 's'
      return
    
    if self.n == 's':
      self.n = 'r'
      return
    
    if self.n == 'r':
      self.rot_r()
      self.n = 'l'
      return
    
  def corner(self):
    c = corners[self.p]
    if c == '/': 
      if self.d == DIR_U or self.d == DIR_D:
        self.rot_r()
      else:
        self.rot_l()
        
      return 
        
    if c == '\\':
      if self.d == DIR_U or self.d == DIR_D:
        self.rot_l()
      else:
        self.rot_r()
      
  def move(self):
    px,py = self.p
    vx,vy = self.d
    
    self.p = (px+vx, py+vy)
    
    if self.p in cross:
      self.cross()
    if self.p in corners:
      self.corner()
      
      
def move_carts():
  pos = set()
  rem = set()

  for c in carts:
    c.move()
    if c.p in pos:
      rem.add(c.p)
    
    pos.add(c.p)
    
  for c in carts:
    if c.p in rem:
      c.dead = True 
    
  if len(rem) > 0:
    print("removed {}, leaving {}".format(len(rem) * 2, len(carts)))
  return None


for y, line in enumerate(input_map.splitlines(), 0):
  for x, c in enumerate(list(line), 0):
    if c == '+':
      cross.add((x,y))
    if c == '/' or c == "\\":
      corners[(x,y)] = c
      
    if c == 'v':
      carts.append(cart(x,y, DIR_D))
    if c == '>':
      carts.append(cart(x,y, DIR_R))
    if c == '^':
      carts.append(cart(x,y, DIR_U))
    if c == '<':
      carts.append(cart(x,y, DIR_L))

      
col = None
while len(carts) > 1:
  col = move_carts()
  carts = [c for c in carts if not c.dead]

x,y = carts[0].p
print("{},{}".format(x, y))
# Out:
# removed 2, leaving 17
# removed 2, leaving 15
# removed 2, leaving 13
# removed 2, leaving 11
# removed 2, leaving 9
# removed 2, leaving 7
# removed 2, leaving 5
# removed 2, leaving 3
# 45,136
